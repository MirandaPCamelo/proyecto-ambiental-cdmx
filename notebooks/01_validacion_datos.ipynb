# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

print("Librerías cargadas correctamente")
# Out:
# Librerías cargadas correctamente

# %%
ruta_shp = "../datos/gis/bases_ambiental/09_ciudaddemexico/conjunto_de_datos/09a.shp"

gdf = gpd.read_file(ruta_shp)

print("Archivo cargado correctamente")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 ruta_shp = "../datos/gis/bases_ambiental/09_ciudaddemexico/conjunto_de_datos/09a.shp"
#       2
# ----> 3 gdf = gpd.read_file(ruta_shp)
#       4
#       5 print("Archivo cargado correctamente")
#
# File c:\Users\pmiri\OneDrive\Desktop\ProyAmbiental\.venv\Lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\pmiri\OneDrive\Desktop\ProyAmbiental\notebooks

# %%
import os

for raiz, carpetas, archivos in os.walk("../datos"):
    for archivo in archivos:
        if archivo.endswith(".shp"):
            print(os.path.join(raiz, archivo))
# Out:
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09a.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09ar.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09cd.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09e.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09ent.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09fm.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09l.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09lpr.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09m.shp
# ../datos\gis\bases_ambiental\bases_ambiental\09_ciudaddemexico\conjunto_de_datos\09mun.shp
# ...

# %%
ruta_shp = r"../datos/gis/bases_ambiental/bases_ambiental/09_ciudaddemexico/conjunto_de_datos/09a.shp"

gdf = gpd.read_file(ruta_shp)

print("Archivo cargado correctamente")
# Out:
# Archivo cargado correctamente

# %%
gdf.head()
# Out:
#           CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0  0900600010185      09     006    0001     0185
# 1  0900600010147      09     006    0001     0147
# 2  0900600010950      09     006    0001     0950
# 3  090060001001A      09     006    0001     001A
# 4  0900600010024      09     006    0001     0024
#
#                                             geometry
# 0  POLYGON ((2806756.715 826178.703, 2806755.107 ...
# 1  POLYGON ((2803973.749 826399.648, 2803957.2 82...
# 2  POLYGON ((2800427.991 823436.207, 2800426.84 8...
# 3  POLYGON ((2806989.953 827836.225, 2806989.898 ...
# 4  POLYGON ((2807871.503 827900.468, 2807867.481 ...

# %%
gdf.columns
gdf.shape
gdf.info()
gdf.crs
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CVEGEO    2430 non-null   str
#  1   CVE_ENT   2430 non-null   str
#  2   CVE_MUN   2430 non-null   str
#  3   CVE_LOC   2430 non-null   str
#  4   CVE_AGEB  2430 non-null   str
#  5   geometry  2430 non-null   geometry
# dtypes: geometry(1), str(5)
# memory usage: 114.0 KB
# <Projected CRS: PROJCS["MEXICO_ITRF_2008_LCC",GEOGCS["ITRF2008",DA ...>
# Name: MEXICO_ITRF_2008_LCC
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: International Terrestrial Reference Frame 2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.plot(figsize=(10,10))

plt.title("AGEBs de la Ciudad de México")
plt.show()
